# %% [markdown]
# ## Kowshik P
#
# ## FairFile - YouTube Comment Scrape
#
# ## Submitted on 27-Jun-2022

# %%
from youtubeComment import youtubeScrape;

obj = youtubeScrape();

# %%
obj.scrape_comments_with_replies(ID = "9VpeTiz81gc")
# Out:
# 'Sucessfull! Check the CSV file that you have just created.'

# %%
obj.fetchingComments()
# Out:
#                          Name  \
# 1               Sakthi Sakthi
# 2                 Jaff Martin
# 3                 Jaff Martin
# 4                 Jaff Martin
# 5                mahesh power
# 6            Rajesh Natarajan
# 7                 Junaid Junu
# 8             5A M.srivarshan
# 9                 satan360974
# 10            shabari shabari
# 11          venkatesh venneti
# 12                Navin Kevin
# 13                 Veera Mani
# 14              Shafi Nasreen
# 15    SCP_ENGINEERING_FACTORY
# 16                 FAHA EDITZ
# 17          N Balasubramanian
# 18            TJ. Babu Joseph
# 19               Murari Rajan
# 20                 Mathan Raj
# 21                   Rohini J
# 22                     PRANAV
# 23                Afsal Iqbal
# 24               vignesh velu
# 25                Mohd Rafeeq
# 26                saji joseph
# 27                 ꧁༺Rishwa༻꧂
# 28           Bala Subramaniam
# 29               sadam sultan
# 30               Lovely Arjun
# ...

# %%
obj.idLength()
# Out:
# 11

# %%
obj.seperateCommentingColumn().head(5)
# Out:
# 0                             👌👌👌👌👌👌👌👌🔥🔥🔥🔥🔥💯❤❤👌👌👌👌👌👌👌👬
# 1                                       Plssssss Sony🙏
# 2    We are waiting for our Aandavar's commercial d...
# 3    Hi sony 🙏 can you please upload this sings ori...
# 4                    Please release VIKRAM OST Volumes
# Name: Comment, dtype: object
